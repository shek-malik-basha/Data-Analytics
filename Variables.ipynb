# %% [markdown]
# <a href="https://colab.research.google.com/github/mehatab-jan/python_Analytics/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creation of variables

# %%
 a = 10
 b = 20
 print(a)
 print(b)
# Out:
# 10
# 20

# %%
name = "Mehatab"
age = 20
print("name:",name)
print("age:",age)
# Out:
# name: Mehatab
# age: 20

# %%
a,b,c = 10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
x=y=z=30
print(x)
print(y)
print(z)
# Out:
# 30
# 30
# 30

# %%
user = input("enter your name")
age = int(input("enter your age"))
print(user)
print(age)
# Out:
# enter your nameMehatab jaan
# enter your age20
# Mehatab jaan
# 20

# %%
a = 10
b = 20
sum = a+b
product = a*b
print(sum)
print(product)
# Out:
# 30
# 200

# %%
numbers = [100,200,300]
a,b,c = numbers
print(a)
print(b)
print(c)
# Out:
# 100
# 200
# 300

# %%
unpack = ("mehatab",20,"AP")
name,age,state = unpack
print(name)
print(age)
print(state)
# Out:
# mehatab
# 20
# AP

# %%
def sum(a,b):
  c = a + b
  return c
sum(10,20)
# Out:
# 30

# %%
def sub(a,b):
  c = a - b
  return c
sub(30,20)
# Out:
# 10

# %%
10a = "me"
print(10a)
# Out:
#   File "/tmp/ipykernel_717/2441152172.py", line 1
#     10a = "me"
#      ^
# SyntaxError: invalid decimal literal

# %%
a = 10
a
# Out:
# 10

# %%
name = "hello"
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_717/613136615.py in <cell line: 0>()
#       1 name = "hello"
# ----> 2 print(Name)
#
# NameError: name 'Name' is not defined

# %%
name = "hello"
Name = "me"
print(name)
print(Name)
# Out:
# hello
# me

# %%
a = 2.2
print(a)
print(type(a))
# Out:
# 2.2
# <class 'float'>

# %%
_numbers = 45
_numbers
# Out:
# 45
